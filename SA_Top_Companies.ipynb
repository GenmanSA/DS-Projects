# %% [markdown]
# <a href="https://colab.research.google.com/github/GenmanSA/DS-Projects/blob/main/SA_Top_Companies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/fts-incoming-funding-zaf-csv-3.csv")

# %%
df
# Out:
#           date         budgetYear  \
# 0        #date  #date+year+budget
# 1   2020-08-11               2020
# 2   2020-07-16                NaN
# 3   2020-07-06                NaN
# 4   2020-07-06                NaN
# 5   2020-06-19                NaN
# 6   2020-06-17                NaN
# 7   2020-06-10                NaN
# 8   2020-06-03                NaN
# 9   2020-05-21                NaN
# 10  2020-05-19                NaN
# 11  2020-05-06               2020
# 12  2020-04-30                NaN
# 13  2020-04-23               2020
# 14  2020-02-14                NaN
# 15  2020-01-13               2020
#
#                                           description  \
# 0                                  #description+notes
# 1   Humanitarian Assistance to Stranded and Vulner...
# 2                           COVID-19 South Africa MCO
# 3         COVID-19 response - South Africa (KM200064)
# 4   (UNICEF-South Africa) COVID-19 response - Sout...
# ...

# %%
df.columns
# Out:
# Index(['date', 'budgetYear', 'description', 'amountUSD', 'srcOrganization',
#        'srcOrganizationTypes', 'srcLocations', 'srcUsageYearStart',
#        'srcUsageYearEnd', 'destPlan', 'destPlanCode', 'destPlanId',
#        'destOrganization', 'destOrganizationTypes', 'destGlobalClusters',
#        'destLocations', 'destProject', 'destProjectCode', 'destEmergency',
#        'destUsageYearStart', 'destUsageYearEnd', 'contributionType',
#        'flowType', 'method', 'boundary', 'onBoundary', 'status',
#        'firstReportedDate', 'decisionDate', 'keywords', 'originalAmount',
#        'originalCurrency', 'exchangeRate', 'id', 'refCode', 'createdAt',
#        'updatedAt'],
#       dtype='object')

# %%
df["description"]
# Out:
# 0                                    #description+notes
# 1     Humanitarian Assistance to Stranded and Vulner...
# 2                             COVID-19 South Africa MCO
# 3           COVID-19 response - South Africa (KM200064)
# 4     (UNICEF-South Africa) COVID-19 response - Sout...
# 5     Providing Urgent Support for Vulnerable Women ...
# 6                            Emergency Funds allocation
# 7     UNFPA Country Office Support to the government...
# 8     Supporting an Inclusive and Multi-Sectoral Res...
# 9     Hygiene, Handwashing & Behaviour Change Coalit...
# 10    Send 7 tons of medical supplies and materials....
# 11      COVID-19 response - South Africa (SM1899100775)
# 12                            COVID-19 South Africa MCO
# 13                       Delegate program (deployments)
# 14                            COVID-19 South Africa MCO
# 15    -,Action B: Emergency Toolbox - SOUTH AFRICA (...
# Name: description, dtype: object

# %%
df2 = pd.read_csv("/content/Top2000CompaniesGlobally.csv")

# %%
df2
# Out:
#       Global Rank                     Company  Sales ($billion)  \
# 0               1                        ICBC             134.8
# 1               2     China Construction Bank             113.1
# 2               3              JPMorgan Chase             108.2
# 3               4            General Electric             147.4
# 4               5                 Exxon Mobil             420.7
# ...           ...                         ...               ...
# 1919         1995              Tractor Supply               4.7
# 1920         1996                  San-Ai Oil               0.5
# 1921         1996                   UOL Group               0.9
# 1922         1998     Interconexion Electrica               2.4
# 1923         1999  Old Republic International               5.0
#
#       Profits ($billion)  Assets ($billion)  Market Value ($billion)  \
# 0                   37.8             2813.5                    237.3
# ...

# %%
df2["Company"]
# Out:
# 0                             ICBC
# 1          China Construction Bank
# 2                   JPMorgan Chase
# 3                 General Electric
# 4                      Exxon Mobil
#                    ...
# 1919                Tractor Supply
# 1920                    San-Ai Oil
# 1921                     UOL Group
# 1922       Interconexion Electrica
# 1923    Old Republic International
# Name: Company, Length: 1924, dtype: object

# %%
filtered_df = df2[df2['Country'] == 'South Africa']

# %%
filtered_df.head(30)
# Out:
#       Global Rank                    Company  Sales ($billion)  \
# 220           231        Standard Bank Group              21.0
# 307           320                      Sasol              20.8
# 333           345                  MTN Group              16.5
# 381           397                  FirstRand               8.4
# 553           574                     Sanlam              10.8
# 902           936          AngloGold Ashanti               6.1
# 931           966    Steinhoff International               9.9
# 951           987              Bidvest Group              16.4
# 1015         1053                    Naspers               5.1
# 1111         1151          Shoprite Holdings              10.1
# 1196         1239                     Remgro               1.7
# 1310         1356               MMI Holdings               6.2
# 1378         1429           Exxaro Resources               1.5
# 1380         1431   Impala Platinum Holdings               3.4
# ...

# %%
filtered_df = df2[df2['Country'] == 'South Africa']

# %%
filtered_df = df2[(df2['Country'] == 'South Africa') & (df2['Profits ($billion)'] < 0.5)]

# %%
filtered_df.head(30)
# Out:
#       Global Rank                    Company  Sales ($billion)  \
# 1015         1053                    Naspers               5.1
# 1111         1151          Shoprite Holdings              10.1
# 1310         1356               MMI Holdings               6.2
# 1600         1658          Imperial Holdings               9.9
# 1651         1711  Aspen Pharmacare Holdings               1.9
#
#       Profits ($billion)  Assets ($billion)  Market Value ($billion)  \
# 1015                 0.4               10.5                     27.7
# 1111                 0.4                3.7                     10.2
# 1310                 0.3               36.8                      4.0
# 1600                 0.4                5.5                      4.2
# 1651                 0.4                3.8                      9.7
#
#            Country Continent   Latitude  Longitude
# 1015  South Africa    Africa -30.559482  22.937506
# 1111  South Africa    Africa -30.559482  22.937506
# ...
